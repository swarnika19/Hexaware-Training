# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
#Create employee data
employee_data = [
    Row(emp_id=101, name="Alice Johnson",  department="HR",          salary=55000),
    Row(emp_id=102, name="Bob Smith",      department="Engineering", salary=85000),
    Row(emp_id=103, name="Carol White",    department="Finance",     salary=70000),
    Row(emp_id=104, name="David Brown",    department="Marketing",   salary=60000),
    Row(emp_id=105, name="Eva Green",      department="Engineering", salary=90000),
]

#Create a DataFrame
df = spark.createDataFrame(employee_data)
display(df)
print("Employee Load Completed")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Alice Johnson</td><td>HR</td><td>55000</td></tr><tr><td>102</td><td>Bob Smith</td><td>Engineering</td><td>85000</td></tr><tr><td>103</td><td>Carol White</td><td>Finance</td><td>70000</td></tr><tr><td>104</td><td>David Brown</td><td>Marketing</td><td>60000</td></tr><tr><td>105</td><td>Eva Green</td><td>Engineering</td><td>90000</td></tr></tbody></table></div>
# Employee Load Completed
